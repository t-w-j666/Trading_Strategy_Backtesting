# %%
# %pip install ipykernel
# %pip install tushare
# %pip install pandas
# %pip install matplotlib
# %pip install pyecharts

# %%
import os
import tushare as ts
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import pyecharts as pc

# %%
#解决matplotlib画图不能显示中文字体的问题（临时解决）
plt.rcParams['font.sans-serif'] = ['SimHei', 'Microsoft YaHei', 'WenQuanYi Micro Hei', 'DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False

# %% [markdown]
# 获取token

# %%
# 从环境变量中读取 token
token = os.environ.get('TUSHARE_TOKEN')
# 初始化 pro 接口 [2]
pro = ts.pro_api(token)

# %% [markdown]
# 连接数据库

# %%
#创建数据库文件连接
conn1=sqlite3.connect('D:\\Cursor项目统一管理\\cursor课程作业\\src\\data\\ETF.db')
conn1.close#close没有加括号的话close(),这个函数不被执行
# Out:
# <function Connection.close()>

# %% [markdown]
# 把数据表存进SQL

# %%
#存数据
#获取ETF基本信息
df = pro.fund_basic()
#获取日线数据
data=pro.fund_daily(ts_code='513310.SH', start_date='19990101', end_date='20260325')
data.to_sql('中韩半导体ETF日线数据',conn1,if_exists='replace',index=False)
conn1.close()

# %% [markdown]
# 从sql拿出数据表

# %%
#取数据
data_read=pd.read_sql("SELECT*FROM 中韩半导体ETF日线数据 ORDER BY trade_date ASC",conn1,parse_dates=['trade_date'])
#index_col='trade_date'
conn1.close()

# %% [markdown]
# 计算指标

# %%
data_read['MA10'] = data_read['close'].rolling(window=10).mean()

# %% [markdown]
# 编写策略函数
# !注意对齐K线图的坐标轴数据数量和数据格式，否则会出现冲突,另外别用日期作为对齐轴

# %%
buy_price=[None]
sell_price=[None]

for i in range(1,len(data_read)):
    cur_data=data_read['close'][i];
    cur_madata=data_read['MA10'][i];
    his_data=data_read['close'][i-1];
    his_madata=data_read['MA10'][i-1];
    if cur_data > cur_madata and his_data < his_madata:
        buy_price.append(data_read['close'][i])
    else:
        buy_price.append(None)
    if cur_data < cur_madata and his_data > his_madata:
        sell_price.append(data_read['close'][i])
    else:
        sell_price.append(None)
    
    
print(buy_price)
print(len(buy_price),len(data_read),len(sell_price))
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.061), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.031), None, None, None, np.float64(1.028), None, None, None, None, None, np.float64(1.043), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.192), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.077), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.178), None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.202), None, None, None, None, None, np.float64(1.202), None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.231), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.148), None, None, np.float64(1.155), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.132), None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.17), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.236), None, None, None, None, None, None, None, None, None, np.float64(1.21), None, np.float64(1.224), None, None, None, None, None, None, None, None, np.float64(1.237), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.144), None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.114), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.25), None, None, np.float64(1.268), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.244), None, None, None, None, None, None, None, None, None, None, np.float64(1.272), None, np.float64(1.267), None, np.float64(1.278), None, None, np.float64(1.273), None, None, None, None, np.float64(1.267), None, np.float64(1.284), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.353), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.32), None, None, None, None, None, None, None, None, np.float64(1.227), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.122), None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.466), None, None, None, None, None, None, None, None, None, None, None, np.float64(1.472), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.406), None, None, None, None, np.float64(1.414), None, None, None, np.float64(1.425), None, None, None, None, None, None, None, None, None, None, None, np.float64(1.452), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.522), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.57), None, np.float64(1.566), None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, np.float64(1.454), None, None, None, None, None, None, None, None, None, None, None, np.float64(1.472), None, None, None, None,  ...
# 785 785 785

# %% [markdown]
# 画K线图

# %%
# 1. 准备数据：[开盘, 收盘, 最低, 最高]
# 假设从之前的 data_read 提取
x_data = data_read['trade_date'].astype(str).tolist()
y_data = data_read[['open', 'close', 'low', 'high']].values.tolist()
x_madata=data_read['MA10']

# 2. 构建 K 线图
kline = (
    pc.charts
    .Kline(init_opts=pc.options.InitOpts( theme=pc.globals.ThemeType.DARK,width="100%", height="100vh",bg_color='#1d1b1c'))
    .add_xaxis(xaxis_data=x_data)
    .add_yaxis(
        series_name="K线图",
        y_axis=y_data,
        # 设置红绿颜色样式
        itemstyle_opts = pc.options.ItemStyleOpts(
            color="red",    # 阳线（涨）
            color0="green",   # 阴线（跌）
            border_color="#8A0000",
            border_color0="#008F28",
        ))
    .set_global_opts(
        title_opts=pc.options.TitleOpts(title="中韩半导体ETF"),
        # 启用你之前需要的缩放功能
        datazoom_opts=[pc.options.DataZoomOpts(type_="slider", min_span=3,range_start=90,range_end=100 ), 
                       pc.options.DataZoomOpts(type_="inside",is_zoom_on_mouse_wheel=True,       # 鼠标滚轮缩放（跟随鼠标位置）
                                               is_move_on_mouse_move=True,        # 鼠标拖拽移动（跟随鼠标）
                                               is_move_on_mouse_wheel=True,       # 鼠标滚轮移动
                                               is_zoom_lock=False,                # 不锁定缩放区域
                                               min_span=5,
                                               )],
        xaxis_opts=pc.options.AxisOpts(splitline_opts=pc.options.SplitLineOpts(is_show=False)), # 去掉 X 轴网格线
        yaxis_opts=pc.options.AxisOpts(is_scale=True,axislabel_opts=pc.options.LabelOpts(
            # 这里的 3 代表强制保留 3 位小数，无论缩放到什么程度都不会改变
                                       formatter=pc.commons.utils.JsCode("function (value) { return value.toFixed(3); }")), # 坐标轴不从0开始
))
)

# 3. 叠加指标
ma_line=(pc.charts.Line()
.add_xaxis(xaxis_data=x_data)
.add_yaxis(series_name="MA10",
    y_axis=x_madata.tolist(),
    is_smooth=True,        # 线条平滑显示
    is_symbol_show=False,
    linestyle_opts=pc.options.LineStyleOpts(width=2),
    itemstyle_opts = pc.options.ItemStyleOpts(color='yellow')
))
kline.overlap(ma_line)

# 3. 渲染
kline.render("etf_kline.html")
# Out:
# 'd:\\Cursor项目统一管理\\cursor课程作业\\src\\实验题目\\etf_kline.html'

# %% [markdown]
# 买卖点绘图

# %%
bs_scatter=(pc.charts.Scatter()
.add_xaxis(xaxis_data=x_data)
.add_yaxis(series_name='B点',
y_axis=buy_price,
symbol_size=15,
itemstyle_opts=pc.options.ItemStyleOpts(color='#e06d34')#更改局部颜色
)
.add_yaxis(series_name='S点',
y_axis=sell_price,
symbol_size=15,
itemstyle_opts=pc.options.ItemStyleOpts(color='#1edda2')#更改局部颜色

)
)

kline.overlap(bs_scatter)
kline.render("etf_kline.html")
# Out:
# 'd:\\Cursor项目统一管理\\cursor课程作业\\src\\实验题目\\etf_kline.html'

# %% [markdown]
# 回测模块

# %%
rmb_init=''
